# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1)Reading the dataset to python environment

# %%
df=pd.read_excel(r"C:\Users\sreeh\Downloads\iris.xls")
display(df)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2)Displaying the columns of df

# %%
list(df.columns)
# Out:
# ['SL', 'SW', 'PL', 'PW', 'Classification']

# %% [markdown]
# # 3)Mean of all columns

# %%
sl=df['SL'].mean()
sw=df['SW'].mean()
pl=df['PL'].mean()
pw=df['PW'].mean()
print("SL = ",sl,"\nSW = ",sw,"\nPL = ",pl,"\nPW = ",pw)
# Out:
# SL =  5.843333333333334
# SW =  3.0540000000000003
# PL =  3.758666666666666
# PW =  1.1986666666666668

# %% [markdown]
# # 4)Checking for null values

# %%
display(df.isnull())
df["Classification"].value_counts()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # 5)Visualization

# %%
x = df["SW"]
y = df["PW"]
plt.xlabel("SW")
plt.ylabel("PW")
plt.title("SW/PW Stem Plot")
plt.stem(x, y) 
plt.show()

# %%
#Scatter Plot
sns.scatterplot(x='SW', y='SL',hue= 'Classification',data=df)
# Out:
# <Axes: xlabel='SW', ylabel='SL'>

# %%
#barPlot
sns.barplot(x="PW",y="Classification",data=df,hue="Classification",errorbar=None)
# Out:
# <Axes: xlabel='PW', ylabel='Classification'>

# %%
sns.barplot(x="SW",y="Classification",data=df,hue="Classification",errorbar=None)
# Out:
# <Axes: xlabel='SW', ylabel='Classification'>

# %%
sns.barplot(x="SL",y="Classification",data=df,hue="Classification",errorbar=None)
# Out:
# <Axes: xlabel='SL', ylabel='Classification'>

# %%
sns.barplot(x="PL",y="Classification",data=df,hue="Classification",errorbar=None)
# Out:
# <Axes: xlabel='PL', ylabel='Classification'>
